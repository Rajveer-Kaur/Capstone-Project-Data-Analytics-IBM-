# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Collecting Job Data Using APIs**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# *   Collect job data using Jobs API
# *   Store the collected data into an excel spreadsheet.

# %% [markdown]
# ><strong>Note: Before starting with the assignment make sure to read all the instructions and then move ahead with the coding part.</strong>

# %% [markdown]
# #### Instructions

# %% [markdown]
# To run the actual lab, firstly you need to click on the [Jobs_API](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Jobs_API.ipynb) notebook link. The file contains flask code which is required to run the Jobs API data.
#
# Now, to run the code in the file that opens up follow the below steps.
#
# Step1: Download the file.
#
# Step2: Upload the file into your current Jupyter environment using the upload button in your Jupyter interface. Ensure that the file is in the same folder as your working .ipynb file.
#
# Step 2: If working in a local Jupyter environment, use the "Upload" button in your Jupyter interface to upload the Jobs_API notebook into the same folder as your current .ipynb file.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Upload.PNG">
#
# Step3:  Open the Jobs_API notebook, and run all the cells to start the Flask application. Once the server is running, you can access the API from the URL provided in the notebook.
#
# If you want to learn more about flask, which is optional, you can click on this link [here](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/FLASK_API.md.html).
#
# Once you run the flask code, you can start with your assignment.

# %% [markdown]
# ## Dataset Used in this Assignment
#
# The dataset used in this lab comes from the following source: https://www.kaggle.com/promptcloud/jobs-on-naukricom under the under a **Public Domain license**.
#
# > Note: We are using a modified subset of that dataset for the lab, so to follow the lab instructions successfully please use the dataset provided with the lab, rather than the dataset from the original source.
#
# The original dataset is a csv. We have converted the csv to json as per the requirement of the lab.

# %% [markdown]
# ## Warm-Up Exercise

# %% [markdown]
# Before you attempt the actual lab, here is a fully solved warmup exercise that will help you to learn how to access an API.

# %% [markdown]
# Using an API, let us find out who currently are on the International Space Station (ISS).<br> The API at [http://api.open-notify.org/astros.json](http://api.open-notify.org/astros.json?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ) gives us the information of astronauts currently on ISS in json format.<br>
# You can read more about this API at [http://open-notify.org/Open-Notify-API/People-In-Space/](http://open-notify.org/Open-Notify-API/People-In-Space?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %%
import requests # you need this module to make an API call
import pandas as pd

# %%
api_url = "http://api.open-notify.org/astros.json" # this url gives use the astronaut data

# %%
response = requests.get(api_url) # Call the API using the get method and store the
                                # output of the API call in a variable called response.

# %%
if response.ok:             # if all is well() no errors, no network timeouts)
    data = response.json()  # store the result in json format in a variable called data
                            # the variable data is of type dictionary.

# %%
print(data)   # print the data just to check the output or for debugging
# Out:
# {'people': [{'craft': 'ISS', 'name': 'Oleg Kononenko'}, {'craft': 'ISS', 'name': 'Nikolai Chub'}, {'craft': 'ISS', 'name': 'Tracy Caldwell Dyson'}, {'craft': 'ISS', 'name': 'Matthew Dominick'}, {'craft': 'ISS', 'name': 'Michael Barratt'}, {'craft': 'ISS', 'name': 'Jeanette Epps'}, {'craft': 'ISS', 'name': 'Alexander Grebenkin'}, {'craft': 'ISS', 'name': 'Butch Wilmore'}, {'craft': 'ISS', 'name': 'Sunita Williams'}, {'craft': 'Tiangong', 'name': 'Li Guangsu'}, {'craft': 'Tiangong', 'name': 'Li Cong'}, {'craft': 'Tiangong', 'name': 'Ye Guangfu'}], 'number': 12, 'message': 'success'}

# %% [markdown]
# Print the number of astronauts currently on ISS.

# %%
print(data.get('number'))
# Out:
# 12

# %% [markdown]
# Print the names of the astronauts currently on ISS.

# %%
astronauts = data.get('people')
print("There are {} astronauts on ISS".format(len(astronauts)))
print("And their names are :")
for astronaut in astronauts:
    print(astronaut.get('name'))
# Out:
# There are 12 astronauts on ISS
# And their names are :
# Oleg Kononenko
# Nikolai Chub
# Tracy Caldwell Dyson
# Matthew Dominick
# Michael Barratt
# Jeanette Epps
# Alexander Grebenkin
# Butch Wilmore
# Sunita Williams
# Li Guangsu
# Li Cong
# Ye Guangfu

# %% [markdown]
# Hope the warmup was helpful. Good luck with your next lab!

# %% [markdown]
# ## Lab: Collect Jobs Data using Jobs API

# %% [markdown]
# ### Objective: Determine the number of jobs currently open for various technologies  and for various locations

# %% [markdown]
# Collect the number of job postings for the following locations using the API:
#
# * Los Angeles
# * New York
# * San Francisco
# * Washington DC
# * Seattle
# * Austin
# * Detroit

# %%
#Import required libraries
import pandas as pd
import json

# %% [markdown]
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json#### Write a function to get the number of jobs for the Python technology.<br>
# > Note: While using the lab you need to pass the **payload** information for the **params** attribute in the form of **key** **value** pairs.
#   Refer the ungraded **rest api lab** in the course **Python for Data Science, AI & Development**  <a href="https://www.coursera.org/learn/python-for-applied-data-science-ai/ungradedLti/P6sW8/hands-on-lab-access-rest-apis-request-http?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01">link</a>
#
#  ##### The keys in the json are
#  * Job Title
#
#  * Job Experience Required
#
#  * Key Skills
#
#  * Role Category
#
#  * Location
#
#  * Functional Area
#
#  * Industry
#
#  * Role
#
# You can also view  the json file contents  from the following <a href = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json">json</a> URL.

# %%
api_url="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json"

def get_number_of_jobs_T(technology):
    #your code goes here   
    payload = {"Key Skills":technology}
    response = requests.get(api_url,payload)
    
    if response.status_code == 200:
        job_list = response.json() #Converting JSON response to Python list
        number_of_jobs = 0
        for job in job_list:
            if technology.lower() in [skill.strip().lower() for skill in job.get('Key Skills','').split('|')]:
                number_of_jobs += 1
        return number_of_jobs
    else:
        print("Failed to fetch data:", response.status_code)
        return 0

# %% [markdown]
# Calling the function for Python and checking if it works.

# %%
get_number_of_jobs_T("Python")
# Out:
# 1165

# %% [markdown]
# #### Write a function to find number of jobs in US for a location of your choice

# %%
 def get_number_of_jobs_L(location):
    
    #your coe goes here
    payload = {'Location' : location}
    response = requests.get(api_url, payload)
    
    if response.status_code == 200:
        job_list = response.json()
        number_of_jobs = 0
        for job in job_list:
            
            if (job.get('Location','').strip().lower() == location.lower()):
                number_of_jobs += 1
    
    return location, number_of_jobs

# %% [markdown]
# Call the function for Los Angeles and check if it is working.

# %%
#your code goes here

get_number_of_jobs_L('los angeles')
# Out:
# ('los angeles', 640)

# %% [markdown]
# ### Store the results in an excel file

# %% [markdown]
# Call the API for all the given technologies above and write the results in an excel spreadsheet.

# %% [markdown]
# If you do not know how create excel file using python, double click here for **hints**.
#
# <!--
#
# from openpyxl import Workbook        # import Workbook class from module openpyxl
# wb=Workbook()                        # create a workbook object
# ws=wb.active                         # use the active worksheet
# ws.append(['Country','Continent'])   # add a row with two columns 'Country' and 'Continent'
# ws.append(['Eygpt','Africa'])        # add a row with two columns 'Egypt' and 'Africa'
# ws.append(['India','Asia'])          # add another row
# ws.append(['France','Europe'])       # add another row
# wb.save("countries.xlsx")            # save the workbook into a file called countries.xlsx
#
#
# -->

# %% [markdown]
# Create a python list of all technologies for which you need to find the number of jobs postings.

# %%
#your code goes here
tech_set = set()
response = requests.get(api_url)
if response.status_code == 200:
    data = response.json()
    
    
    for job in data:
        key_skills = job.get('Key Skills','') #Get 'Key Skills' field
    
        if key_skills: #Checks if 'key_skills' is nor Empty
            skills = [skill.strip() for skill in key_skills.split('|')] # Split and clean the skills
            tech_set.update(skills) # Add all skills to the set (ensuring uniqueness)
            
                
tech_list = list(tech_set)
print(tech_list)
# Out:
# ['', 'Studio', 'denial management', 'Event Manager', 'Wi - Fi', 'asp net mvc', 'Manager - Marketing', 'catering sales', 'cardiology', 'review', 'Technical Consultancy', 'Java coding', 'hi', 'Residential', 'duty manager', 'retail operation', 'Campus interviews', 'crop', 'language specialist', 'professional tax', 'back office processing', 'Web Analytics', 'Channel Partner Management', 'Channel Manager', 'Sql Tuning', 'dicom', 'Promotions', 'academic counselor', 'Java Servlets', 'Lead Administrator', 'QE', 'o2c', 'general', 'SAP Workflow', 'construction engineering', 'troubleshooting', 'FI - AP', 'Domain Analyst', 'Kubernetes', 'involving all relevant stakeholders and ensuring technica', 'consolidation', 'Term Deposits', 'Statistical modeling', 'api', 'PRO II', 'Web designing', 'Transaction Banking', 'program', 'Energy Conservation', 'user stories', '2d graphics', 'Back Office Management', 'Angular', 'shipping lines', 'Feasibility Analysis', 'medical devices sales', 'fraud analytics', 'net 3 5', 'telecom', 'tibco', 'control testing', 'Net', 'willing to learn', 'Quality Analysis', 'bolt operator', 'Process Setting', 'detailing', 'Linux Admin', 'Gas turbine', 'Receivable', 'Stringing', 'Team Orientation', 'Omega', 'Reference Data', 'axis', 'Technical management', 'front office executive', 'rendering', 'micro - controller', 'Neural Networks', 'Consumer Electronics', 'SQR', 'Product Training', 'Cable Tray', 'Safety Supervisor', 'Negotiation', 'Building Management System', 'Back Office Staff', 'Credit cards', 'Linguistics', 'javaScript', 'GATP', 'Saving', 'Investment products', 'Must have hands on experience in making various kinds of coffee Experience with', 'Retention', 'refund', 'VLR', 'HR activities', 'call coach', 'billing engineer', 'oracle 11g', 'Commercial Operations', 'object - oriented design', 'System Engineering', 'Heating', 'Middle Office', 'capex', 'intensive care', 'ielts', 'premier banking', 'Process Controller', 'Sales & Marketing', 'ADO.Net', 'credit control', 'Art', 'medical records', 'Facility Administration', 'uk shifts', 'change', 'XenApp', 'PPTP', 'Case Studies', 'wpa', 'Safety Training', 'Branch Banking Operations', 'sanitary ware', 'Trigger', 'MIL', 'ERP (Consultants/Sr. Consultants)', 'Accounts finalization', 'Sales Enablement', 'Elixir', 'German Translator', 'TRAINEE', 'Visual Merchandising', 'Technology operations', 'customer services', 'ADAS', 'Cost Management', 'loans', 'financial markets', 'cut colour wash dry shave', 'radio - diagnosis', 'Hostess', 'cp', 'Safety Management', 'Institutional Sales.', 'event planning', 'QMP', 'Fanuc Controller', 'IT Project Management', 'EMO', 'Stress analysis', 'Overseas Marketing', 'Language Expert', 'Consumer Insights', 'bobj', 'country management', 'Call Manager Express', 'Automation anywhere', 'Background Verification', 'payroll accounting', 'corporate development', 'data loader', 'management assistant', 'ironport', 'oracle bi developer', 'Plastic injection moulding', 'postpaid sales', 'Calls', 'Institutional sales', 'AutoPlant', 'Enterprise Business', 'NON VOICE', 'Usa', 'recruitment', 'User Interface Designing', 'vendor evaluation', 'Sales Coordination', 'cisco unified communications', 'Spend Analysis', 'Internet technologies', 'vault', 'supply chain operations', 'optimization', 'Customer Profiling', 'Retail Sales Executive', 'industrial valves', 'rrc', 'Ethernet', 'RF Design', 'Contract negotiations', 'vmc programmer', 'qtp', 'cdma', 'UI Designer', 'Network Testing', 'Fraud management', 'PQR', 'call quality analyst', 'angel broking', 'Content strategy', 'Zend', 'academic qualification', 'Value Added Services', 'lifestyle', 'Data Processor', 'Client Development', 'Technical Trainer', 'Brand Marketing Manager', 'anatomy', 'document specialist', 'Load Balancing', 'dotnet developer', 'Water supply', 'code ignitor', 'Robotics', 'Sales Engineer', 'Team center', 'Futures', 'Microsoft dynamics NAV', 'electronics diploma', 'DHCP', 'Project Administration', 'dupont', 'IMS',  ...

# %% [markdown]
# Import libraries required to create excel spreadsheet

# %%
#your code goes here
loc_list = []
response = requests.get(api_url)
if response.status_code == 200:
    data = response.json()
    
    for loc in data:
        location = loc.get('Location') #Get 'Location' field
        if location not in loc_list:
            loc_list.append(location)
print(loc_list)
# Out:
# ['Los Angeles', 'New York', 'San Francisco', 'Washington DC', 'Boston', 'Seattle', 'Detroit', 'Austin', 'Houston', 'Philadelphia', 'New Orleons', 'Baltimore', 'Dallas']

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (3.1.3)
# Requirement already satisfied: et-xmlfile in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# your code goes here
from openpyxl import Workbook

# %% [markdown]
# Create a workbook and select the active worksheet

# %%
# your code goes here
wb = Workbook()
ws = wb.active

# %% [markdown]
# Find the number of jobs postings for each of the technology in the above list.
# Write the technology name and the number of jobs postings into the excel spreadsheet.

# %%
ws.append(['Location', 'Number of Jobs'])

# %%
for loc in loc_list:
    count = get_number_of_jobs_L(loc)[1]
    ws.append([loc,count])

# %% [markdown]
# Save into an excel spreadsheet named **job-postings.xlsx**.

# %%
#your code goes here
wb.save("job_postings_1.xlsx")

# %%
df = pd.read_excel("job_postings_1.xlsx")
df.head(10)
# Out:
#         Location  Number of Jobs
# 0    Los Angeles             640
# 1       New York            3226
# 2  San Francisco             435
# 3  Washington DC            5316
# 4         Boston            2966
# 5        Seattle            3375
# 6        Detroit            3945
# 7         Austin             434
# 8        Houston            3339
# 9   Philadelphia              41

# %% [markdown]
# #### In the similar way, you can try for below given technologies and results  can be stored in an excel sheet.

# %% [markdown]
# Collect the number of job postings for the following languages using the API:
#
# *   C
# *   C#
# *   C++
# *   Java
# *   JavaScript
# *   Python
# *   Scala
# *   Oracle
# *   SQL Server
# *   MySQL Server
# *   PostgreSQL
# *   MongoDB

# %%
# your code goes here
lang = ['C', 'C#', 'C++', 'Java', 'JavaScript', 'Python', 'Scala', 'Oracle', 'SQL Server', 'MySQL Server', 
       'PostgreSQL', 'MongoDB']

wb = Workbook()
ws = wb.active
ws.append(['Technology', 'Number of Jobs'])
for tech in lang:
    count = get_number_of_jobs_T(tech)
    ws.append([tech,count])
    
wb.save('job_postings_2.xlsx')

# %%
df = pd.read_excel('job_postings_2.xlsx')
df
# Out:
#       Technology  Number of Jobs
# 0              C             817
# 1             C#             487
# 2            C++             496
# 3           Java            1209
# 4     JavaScript            2241
# 5         Python            1165
# 6          Scala              89
# 7         Oracle             614
# 8     SQL Server             310
# 9   MySQL Server               0
# 10    PostgreSQL              86
# 11       MongoDB             208

# %% [markdown]
# ## Authors

# %% [markdown]
# Ayushi Jain

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja
#
# Lakshmi Holla
#
# Malika

# %% [markdown]
# Copyright © IBM Corporation.

# %% [markdown]
# <!--## Change Log

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2022-01-19        | 0.3     | Lakshmi Holla        | Added changes in the markdown      |
# | 2021-06-25        | 0.2     | Malika            | Updated GitHub job json link       |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |--!>
